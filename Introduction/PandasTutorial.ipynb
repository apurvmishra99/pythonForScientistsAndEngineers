# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
#Hubble Space Telescope

# %%
# !wget https://raw.githubusercontent.com/shantnu/Intro-to-Pandas/master/hubble_data.csv
# Out:
# --2018-07-18 15:08:30--  https://raw.githubusercontent.com/shantnu/Intro-to-Pandas/master/hubble_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.152.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.152.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 222 [text/plain]
# Saving to: ‘hubble_data.csv’
#
# hubble_data.csv     100%[===================>]     222  --.-KB/s    in 0s
#
# 2018-07-18 15:08:31 (16.8 MB/s) - ‘hubble_data.csv’ saved [222/222]

# %%
data = pd.read_csv('hubble_data.csv')

# %%
data
# Out:
#     distance  recession_velocity
# 0      0.032                 170
# 1      0.034                 290
# 2      0.214                -130
# 3      0.263                 -70
# 4      0.275                -185
# 5      0.275                -220
# 6      0.450                 200
# 7      0.500                 290
# 8      0.500                 270
# 9      0.630                 200
# 10     0.800                 300
# 11     0.900                 -30
# 12     0.900                 650
# 13     0.900                 150
# 14     0.900                 500
# 15     1.000                 920
# 16     1.100                 450
# 17     1.100                 500
# 18     1.400                 500
# 19     1.700                 960
# 20     2.000                 500
# 21     2.000                 850
# 22     2.000                 800
# 23     2.000                1090

# %%
data.head()
# Out:
#    distance  recession_velocity
# 0     0.032                 170
# 1     0.034                 290
# 2     0.214                -130
# 3     0.263                 -70
# 4     0.275                -185

# %%
# !wget https://raw.githubusercontent.com/shantnu/Intro-to-Pandas/master/hubble_data_no_headers.csv
# Out:
# --2018-07-18 15:11:27--  https://raw.githubusercontent.com/shantnu/Intro-to-Pandas/master/hubble_data_no_headers.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.152.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.152.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194 [text/plain]
# Saving to: ‘hubble_data_no_headers.csv’
#
# hubble_data_no_head 100%[===================>]     194  --.-KB/s    in 0s
#
# 2018-07-18 15:11:28 (14.7 MB/s) - ‘hubble_data_no_headers.csv’ saved [194/194]

# %%
headers = ['dist', 'rec_vel']

# %%
data_no_headers = pd.read_csv('hubble_data_no_headers.csv', names = headers)

# %%
data_no_headers.head()
# Out:
#     dist  rec_vel
# 0  0.032      170
# 1  0.034      290
# 2  0.214     -130
# 3  0.263      -70
# 4  0.275     -185

# %%
data_no_headers['dist']
# Out:
# 0     0.032
# 1     0.034
# 2     0.214
# 3     0.263
# 4     0.275
# 5     0.275
# 6     0.450
# 7     0.500
# 8     0.500
# 9     0.630
# 10    0.800
# 11    0.900
# 12    0.900
# 13    0.900
# 14    0.900
# 15    1.000
# 16    1.100
# 17    1.100
# 18    1.400
# 19    1.700
# 20    2.000
# 21    2.000
# 22    2.000
# 23    2.000
# Name: dist, dtype: float64

# %%
data.set_index("distance", inplace = True)

# %%
data.head()
# Out:
#           recession_velocity
# distance
# 0.032                    170
# 0.034                    290
# 0.214                   -130
# 0.263                    -70
# 0.275                   -185

# %%
data.plot()
plt.show()

# %%
#US Labour Wages

# %%
# !wget https://raw.githubusercontent.com/shantnu/Intro-to-Pandas/master/wages_hours.csv
# Out:
# --2018-07-18 15:20:03--  https://raw.githubusercontent.com/shantnu/Intro-to-Pandas/master/wages_hours.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.152.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.152.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1935 (1.9K) [text/plain]
# Saving to: ‘wages_hours.csv’
#
# wages_hours.csv     100%[===================>]   1.89K  --.-KB/s    in 0s
#
# 2018-07-18 15:20:05 (20.8 MB/s) - ‘wages_hours.csv’ saved [1935/1935]

# %%
data1 = pd.read_csv("wages_hours.csv")
data1
# Out:
#    HRS\tRATE\tERSP\tERNO\tNEIN\tASSET\tAGE\tDEP\tRACE\tSCHOOL
# 0   2157\t2.905\t1121\t291\t380\t7250\t38.5\t2.340...
# 1   2174\t2.970\t1128\t301\t398\t7744\t39.3\t2.335...
# 2   2062\t2.350\t1214\t326\t185\t3068\t40.1\t2.851...
# 3   2111\t2.511\t1203\t49\t117\t1632\t22.4\t1.159\...
# 4   2134\t2.791\t1013\t594\t730\t12710\t57.7\t1.22...
# 5   2185\t3.040\t1135\t287\t382\t7706\t38.6\t2.602...
# 6   2210\t3.222\t1100\t295\t474\t9338\t39.0\t2.187...
# 7   2105\t2.493\t1180\t310\t255\t4730\t39.9\t2.616...
# 8   2267\t2.838\t1298\t252\t431\t8317\t38.9\t2.024...
# 9   2205\t2.356\t885\t264\t373\t6789\t38.8\t2.662\...
# 10  2121\t2.922\t1251\t328\t312\t5907\t39.8\t2.287...
# 11  2109\t2.499\t1207\t347\t271\t5069\t39.7\t3.193...
# 12  2108\t2.796\t1036\t300\t259\t4614\t38.2\t2.040...
# 13  2047\t2.453\t1213\t297\t139\t1987\t40.3\t2.545...
# 14  2174\t3.582\t1141\t414\t498\t10239\t40.0\t2.06...
# 15  2067\t2.909\t1805\t290\t239\t4439\t39.1\t2.301...
# ...

# %%
#Messed up output due to absence of of commas as separators

# %%
#We use sep = '\t' in read_csv to make sense of data

# %%
data_1 = pd.read_csv("wages_hours.csv", sep = '\t')

# %%
data_1
# Out:
#      HRS   RATE  ERSP ERNO  NEIN  ASSET   AGE    DEP  RACE  SCHOOL
# 0   2157  2.905  1121  291   380   7250  38.5  2.340  32.1    10.5
# 1   2174  2.970  1128  301   398   7744  39.3  2.335  31.2    10.5
# 2   2062  2.350  1214  326   185   3068  40.1  2.851     *     8.9
# 3   2111  2.511  1203   49   117   1632  22.4  1.159  27.5    11.5
# 4   2134  2.791  1013  594   730  12710  57.7  1.229  32.5     8.8
# 5   2185  3.040  1135  287   382   7706  38.6  2.602  31.4    10.7
# 6   2210  3.222  1100  295   474   9338  39.0  2.187  10.1    11.2
# 7   2105  2.493  1180  310   255   4730  39.9  2.616  71.1     9.3
# 8   2267  2.838  1298  252   431   8317  38.9  2.024   9.7    11.1
# 9   2205  2.356   885  264   373   6789  38.8  2.662  25.2     9.5
# 10  2121  2.922  1251  328   312   5907  39.8  2.287  51.1    10.3
# 11  2109  2.499  1207  347   271   5069  39.7  3.193     *     8.9
# 12  2108  2.796  1036  300   259   4614  38.2  2.040     *     9.2
# ...

# %%
data2 = data_1[['AGE','RATE']]

# %%
data2.head()
# Out:
#     AGE   RATE
# 0  38.5  2.905
# 1  39.3  2.970
# 2  40.1  2.350
# 3  22.4  2.511
# 4  57.7  2.791

# %%
data_sorted = data2.sort_values(['AGE'])

# %%
data_sorted
# Out:
#      AGE   RATE
# 3   22.4  2.511
# 27  37.2  3.015
# 31  37.4  1.901
# 33  37.5  1.899
# 32  37.5  3.009
# 17  37.9  2.516
# 30  38.2  3.273
# 12  38.2  2.796
# 29  38.4  3.010
# 0   38.5  2.905
# 5   38.6  3.040
# 9   38.8  2.356
# 8   38.9  2.838
# 6   39.0  3.222
# 26  39.0  2.912
# 19  39.1  3.636
# 38  39.1  3.413
# 15  39.1  2.909
# 36  39.2  2.980
# 34  39.2  2.959
# 1   39.3  2.970
# 16  39.3  2.511
# 35  39.4  2.971
# 22  39.5  3.262
# 11  39.7  2.499
# 20  39.8  2.983
# 10  39.8  2.922
# 23  39.8  3.234
# 7   39.9  2.493
# 21  40.0  2.573
# 14  40.0  3.582
# 2   40.1  2.350
# 13  40.3  2.453
# 37  40.5  2.630
# 18  40.6  1.423
# 24  40.6  2.280
# 25  41.8  2.304
# 28  43.4  2.786
# 4   57.7  2.791

# %%
data_sorted.set_index('AGE', inplace = True)

# %%
data_sorted.head()
# Out:
#        RATE
# AGE
# 22.4  2.511
# 37.2  3.015
# 37.4  1.901
# 37.5  1.899
# 37.5  3.009

# %%
data_sorted.plot()
plt.show()
